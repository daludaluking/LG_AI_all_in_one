# %% [markdown]
# ### 문제 1
# 20이하의 자연수 중 3으로 나눴을 때 나머지가 1인 숫자를 출력하기

# %%
# 정답을 작성해주세요.
# Out:
# 1
# 4
# 7
# 10
# 13
# 16
# 19

# %% [markdown]
# ### 문제 2
# 다음과 같이 출력하기
# \*
# \**
# \*\*\*
# \*\*\*\*
# \*\*\*\*\*

# %%
# 정답을 작성해주세요.
# Out:
# *
# **
# ***
# ****
# *****

# %% [markdown]
# ### 문제 3
# 고객의 개인정보보호를 위하여 이름을 비식별화 하여 출력하기
# 예시) 홍길동 → 홍\*동

# %%
names = ['홍길동', '홍계월', '김철수', '이영희', '박첨지']

# %%
# 정답을 작성해주세요.
# Out:
# 홍*동
# 홍*월
# 김*수
# 이*희
# 박*지
