# %% [markdown]
# # 1. 표준 입출력
# ### 출력

# %%
print("하나","둘","셋",1,2,3) 
print("하나","둘","셋",1,2,3,sep='-') 
print("첫번째 값")
print("두번째 값") # 다른 줄에 출력
print("첫번째 값", end=" ---> ")
print("두번째 값") # 같은 줄에 출력
#a = input()
#print(a)
# Out:
# 하나 둘 셋 1 2 3
# 하나-둘-셋-1-2-3
# 첫번째 값
# 두번째 값
# 첫번째 값 ---> 두번째 값
# asdjlfaksjdfklajsdlkfja

# %% [markdown]
# ### 출력 방향 변경

# %%
file = open("hello_world.txt","w")
print(type(file))
print("hello, world!", file=file) # 파일로 출력
file.close()
# Out:
# <class '_io.TextIOWrapper'>

# %% [markdown]
# ### 포매팅
# #### (1) %

# %%
num = 1

# %%
print('문자열 포맷팅 하기 예시 %d' %num)
print(f'문자열 포맷팅 하기 예시 {num}')
# Out:
# 문자열 포맷팅 하기 예시 1
# 문자열 포맷팅 하기 예시 1

# %%
ch = '이름'

# %%
print('내 이름은 : %s' %ch)
# Out:
# 내 이름은 : 이름

# %%
fl = 2.566132

# %%
print('반올림 하기 : %0.1f' %fl)
# Out:
# 반올림 하기 : 2.6

# %%
a = 3
b = 5

# %%
print('%d 와 %d 를 더하면 %d' %(a,b,a+b))
# Out:
# 3 와 5 를 더하면 8

# %% [markdown]
# #### (2) format

# %%
print('문자열 포맷팅 하기 예시 {}'.format(2))
# Out:
# 문자열 포맷팅 하기 예시 2

# %%
print('내 이름은 : {}'.format(ch))
# Out:
# 내 이름은 : 이름

# %%
fl = 2138.8728829
print('소수점 포맷팅하기 : {:.3f}'.format(fl))
# Out:
# 소수점 포맷팅하기 : 2138.873

# %%
round(fl, 3)
# Out:
# 2138.873

# %%
ln = '서'
fn = '상현'

# %%
print('성은 {}, 이름은 {}'.format(ln, fn))
# Out:
# 성은 서, 이름은 상현

# %%
print('성은 {0}, 이름은 {1}'.format(ln, fn))
# Out:
# 성은 서, 이름은 상현

# %%
print('First name : {1}, Last name : {0}'.format(ln, fn))
# Out:
# First name : 상현, Last name : 서

# %%
커피 = '커피'
print('나는 오늘 {음료}를 {개수} 잔이나 마셨다'.format(음료=커피, 개수=3))
# Out:
# 나는 오늘 커피를 3 잔이나 마셨다

# %% [markdown]
# #### 길이와 정렬

# %%
print('Python is [{:15}]'.format('good'))
print('Python is [{:<15}]'.format('good'))
print('Python is [{:>15}]'.format('good'))
print('Python is [{:^15}]'.format('good'))
print('당신의 나이는 [{:15}]세'.format(22))
print('당신의 나이는 [{:<15}]세'.format(22))
print('당신의 나이는 [{:>15}]세'.format(22))
print('당신의 나이는 [{:<15}]세'.format(22))
# Out:
# Python is [good           ]
# Python is [good           ]
# Python is [           good]
# Python is [     good      ]
# 당신의 나이는 [             22]세
# 당신의 나이는 [22             ]세
# 당신의 나이는 [             22]세
# 당신의 나이는 [22             ]세

# %%
# 0으로 채우기
for x in range(1, 4):
    print('[{0:02d}] [{1:03d}] [{2:04d}]'.format(x, x*x, x*x*x))
print()
# 부호 출력
print('[{0:05d}] [{1:05d}] [{2:05d}]'.format(1,-2,3))    # 음수만 부호
print('[{0:+05d}] [{1:+05d}] [{2:+05d}]'.format(1,-2,3)) # 부호
print('[{0:<5d}] [{1:<5d}] [{2:<5d}]'.format(1,-2,3))     # 정렬
# Out:
# [01] [001] [0001]
# [02] [004] [0008]
# [03] [009] [0027]
#
# [00001] [-0002] [00003]
# [+0001] [-0002] [+0003]
# [1    ] [-2   ] [3    ]

# %%
# 채움문자
print('[{0:05d}] [{1:05d}] [{2:05d}]'.format(1,-2,3))
print('[{0:★<5d}] [{1:★<5d}] [{2:★<5d}]'.format(1,-2,3))
print('[{0:★>5d}] [{1:★>5d}] [{2:★>5d}]'.format(1,-2,3))
print('[{0:★^5d}] [{1:★^5d}] [{2:★^5d}]'.format(1,-2,3))
print('[{0:5d}] [{1:5d}] [{2:5d}]'.format(1,-2,3))
print('[{0:=5d}] [{1:=5d}] [{2:=5d}]'.format(1,-2,3))
print('[{0:=05d}] [{1:=05d}] [{2:=05d}]'.format(1,-2,3))
# 숫자 표시 형식( , _) 
print('[{0:>5,}] [{1:>5,}] [{2:>5,}]'.format(11544435,-2544254,35454343))
print('[{0:>5_}] [{1:>5_}] [{2:>5_}]'.format(11544435,-2544254,35454343))
print('[{0:>5e}] [{1:>5e}] [{2:>5e}]'.format(11544435,-2544254,35454343))
# Out:
# [00001] [-0002] [00003]
# [1★★★★] [-2★★★] [3★★★★]
# [★★★★1] [★★★-2] [★★★★3]
# [★★1★★] [★-2★★] [★★3★★]
# [    1] [   -2] [    3]
# [    1] [-   2] [    3]
# [00001] [-0002] [00003]
# [11,544,435] [-2,544,254] [35,454,343]
# [11_544_435] [-2_544_254] [35_454_343]
# [1.154444e+07] [-2.544254e+06] [3.545434e+07]

# %% [markdown]
# #### (3) f 문자열 포맷팅
# 파이썬 3.6부터 지원

# %%
year = 2020

# %%
f'올해는 {year}'
# Out:
# '올해는 2020'

# %% [markdown]
# #### 다른 포맷팅과의 차이점

# %%
'나는 오늘 %s 를 %d + 1 잔이나 마셨다' %('커피', 3)
# Out:
# '나는 오늘 커피 를 3 + 1 잔이나 마셨다'

# %%
'나는 오늘 {음료}를 {개수+1} 잔이나 마셨다'.format(음료='커피', 개수=3)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-21356a636e64> in <module>
# ----> 1 '나는 오늘 {음료}를 {개수+1} 잔이나 마셨다'.format(음료='커피', 개수=3)
#
# KeyError: '개수+1'

# %%
'나는 오늘 {음료}를 {개수+1} 잔이나 마셨다'.format(음료='커피', 개수+1=3)
# Out:
#   File "<ipython-input-32-2a7fb5473071>", line 1
#     '나는 오늘 {음료}를 {개수+1} 잔이나 마셨다'.format(음료='커피', 개수+1=3)
#
# ^
# SyntaxError: expression cannot contain assignment, perhaps you meant "=="?

# %%
drink = '커피'
nums = 3

# %%
f'나는 오늘 {drink}를 {nums + 1} 잔이나 마셨다'
# Out:
# '나는 오늘 커피를 4 잔이나 마셨다'

# %% [markdown]
# #### (4) 딕셔너리 포맷팅

# %%
s = {'name': 'IBM',
    'shares': 100,
    'price': 91.1}

# %%
'{name:>10s}{shares:10d}{price:10.2f}'.format_map(s)
# Out:
# '       IBM       100     91.10'

# %% [markdown]
# # 2. 사용자 입력
# ### input() 사용

# %%
# Life is too short, you need python 입력
a = input()

# %%
a
# Out:
# 'aaaaaa'

# %%
number = input("숫자를 입력하세요: ")

# %%
number
# Out:
# '123'

# %%
integer = int(input("정수형 숫자를 입력하세요: "))
integer
# Out:
# 123

# %%
real = float(input("실수형 숫자를 입력하세요: "))
real
# Out:
# 2.3

# %%
while True:
    try:
        integer = int(input("정수형 숫자를 입력하세요: "))
        break
    except ValueError as e:
        print(e)
        continue
integer
# Out:
# invalid literal for int() with base 10: '1.2'
# invalid literal for int() with base 10: ''
# 1

# %% [markdown]
# # 3. 파일
# #### 구글 드라이브 연동

# %%
import os
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
print(os.getcwd())
# Out:
# /media/dalu/data/projects/LG_AI_all_in_one/python/practice

# %%
#os.chdir('/content/drive/My Drive/Lectures/LG_Electronics/python/day2')
os.chdir('./day2')
print(os.getcwd())
# Out:
# /media/dalu/data/projects/LG_AI_all_in_one/python/practice/day2

# %% [markdown]
# ## 2. 파일 쓰기
# ### 1-0. 파일?

# %% [markdown]
# file name : new.txt
# 상대 경로 :
# 절대 경로 :

# %% [markdown]
# ### 1-1. 파일 쓰기

# %%
file_path_1 = './news1.txtaaaa'
new_file = open(file_path_1, 'w')

# %%
from os import path
print(new_file.name)
path.abspath(new_file.name)
# Out:
# ./news1.txtaaaa
# '/media/dalu/data/projects/LG_AI_all_in_one/python/practice/day2/news1.txtaaaa'

# %%
data = '새로운 내용을 쓰고 싶다면,\n이렇게 작성하면 됩니다.'

# %%
new_file.write(data)
# Out:
# 29

# %%
new_file.close()

# %% [markdown]
# ### 1-2. with문을 활용하여 파일 쓰기

# %%
file_path_2 = './new2.txt'
with open(file_path_2, 'w') as f :
    data = '이렇게도 작성이 가능합니다. close를 따로 안해도 돼요.'
    f.write(data)

# %% [markdown]
# ### 2. 파일 읽기

# %%
file_path_1 = './news2.txt'
with open(file_path_1, 'r') as f:
    lines = f.read()
    print(lines)
    print(type(lines))
# Out:
# 중앙일보
#
# [단독]"돈 먼저 보자" 마스크 105만장 역대 최대 사재기 적발
#
# 문재인 대통령(오른쪽 두 번째)과 홍남기 경제부총리 등 정부 관계자들이 지난 6일 부산에서 열린 '일자리 상생협약식'에서 마스크를 쓰고 있다. [청와대사진기자단]
# 신종 코로나바이러스 감염증(우한 폐렴) 관련 마스크 매점매석(買占賣惜ㆍ사재기) 행위가 기승을 부리는 가운데 정부가 역대 최대 규모 마스크 사재기 행위를 적발했다. 한 번에 적발한 규모만 105만장 수준이다.
#
# 식품의약품안전처 위해사범중앙조사단은 사재기한 마스크를 국내 최대 중고거래 사이트인 네이버 ‘중고나라’를 통해 팔려고 시도한 경북 의성의 한 마스크 제조업체 관계자 A씨를 현장 적발했다고 10일 밝혔다. A씨는 지난 7일 중고나라에 “마스크 105만장을 판매한다”는 글을 올렸다. 제시한 가격은 14억원(개당 약 1300원).
#
# 조사단 관계자는 글을 보자마자 구매자로 위장해 A씨와 접촉을 시도했다. A씨는 “정말 살 생각이 있느냐” “돈을 먼저 보여달라” “먼저 입금해 달라”며 수차례 접촉 장소 변경을 요구했다. 결국 조사단원은 제조업체 창고에서 A씨를 만났다.
#
# 창고에는 ‘박스 갈이(택배 상자에 옮겨 담은 것)’한 마스크 박스 수백 상자가 가득 쌓여있었다. 조사결과 A씨는 7억원 어치 마스크를 14억원에 판매하려고 한 것으로 나타났다. 홍헌우 조사단장은 “105만장은 매점매석 행위 단속을 시작한 후 역대 최대 규모”라며 “마스크 거래처를 찾는 업자가 중고거래 사이트로 몰리고 있다”고 설명했다. 조사단은 A씨 등을 경찰에 고발할 예정이다.
#
# 식약처 위해사범중앙조사단이 지난 6일 경기도 용인의 한 마스크 도매업체 창고에서 사재기 행위를 단속하고 있다. [연합뉴스]
#
# 정부가 판단하는 매점매석 기준은 조사 당일 기준으로 지난해 월평균 판매량의 150%를 초과해 5일 이상 보관할 경우다. 지난해 신규 사업자는 영업 시작일부터 조사 당일까지 월평균 판매량을 기준으로 매점매석 여부를 판단한다. 영업 2개월 미만 사업자는 매입한 날부터 10일 이내에 반환ㆍ판매하지 않을 경우 해당한다. 조사단은 해당 업체 마스크 보관량이 지난해 월평균 판매량의 150%가 넘는 만큼 사재기로 보고 있다. 매점매석 행위는 물가안정에 관한 법률에 따라 2년 이하 징역 혹은 5000만원 이하 벌금형을 받을 수 있다.
#
# 조사단은 국내 ‘마스크 대란’을 돈벌이로 활용하기 위해 여전히 재고물량을 쌓아놓은 업체가 많은 것으로 보고 있다. 지난 6일 기준 국내 마스크 1일 생산 규모는 900만장이다. 신종 코로나 발병 이전 하루 200만~300만장 규모에서 크게 늘었다. 식약처가 이번에 적발한 업체 한 곳에서만 국내 하루 생산량의 10%가 넘는 마스크를 보관하고 있었다.
#
# 정부는 마스크 사재기 단속 강도를 높이고 있다. 지난 4일부터 식약처와 경찰ㆍ관세청 등이 참여한 정부합동단속반을 확대 운영하고 매점매석 행위 금지를 고시했다. 고시 이틀 만에 700여건의 신고가 접수될 정도로 불법행위는 극성을 부렸다. 11일부터는 1976년 이후 44년 만에 마스크 ‘긴급수급조정조치’를 시행할 계획이다. 조치를 시행하면 마스크 생산ㆍ판매자가 생산량ㆍ판매량ㆍ단가 등을 의무 신고해야 한다. 기획재정부 관계자는 “마스크 생산→유통→판매로 이어지는 전 과정이 투명해져 사재기나 해외 밀반출 가능성을 사전에 차단할 것으로 기대한다”고 말했다.
#
# 세종=김기환 기자 khkim@joongang.co.kr
#
# <class 'str'>

# %%
with open(file_path_1, 'r') as f:
    line = f.readline()
    print(line)
    print(type(line))
# Out:
# 중앙일보
#
# <class 'str'>

# %%
with open(file_path_1, 'r') as f:
    while True :
        line = f.readline()
        if not line : break
        #if line is None: break
        print(line)
# Out:
# 중앙일보
#
#
#
# [단독]"돈 먼저 보자" 마스크 105만장 역대 최대 사재기 적발
#
#
#
# 문재인 대통령(오른쪽 두 번째)과 홍남기 경제부총리 등 정부 관계자들이 지난 6일 부산에서 열린 '일자리 상생협약식'에서 마스크를 쓰고 있다. [청와대사진기자단]
#
# 신종 코로나바이러스 감염증(우한 폐렴) 관련 마스크 매점매석(買占賣惜ㆍ사재기) 행위가 기승을 부리는 가운데 정부가 역대 최대 규모 마스크 사재기 행위를 적발했다. 한 번에 적발한 규모만 105만장 수준이다.
#
#
#
# 식품의약품안전처 위해사범중앙조사단은 사재기한 마스크를 국내 최대 중고거래 사이트인 네이버 ‘중고나라’를 통해 팔려고 시도한 경북 의성의 한 마스크 제조업체 관계자 A씨를 현장 적발했다고 10일 밝혔다. A씨는 지난 7일 중고나라에 “마스크 105만장을 판매한다”는 글을 올렸다. 제시한 가격은 14억원(개당 약 1300원).
#
#
#
# 조사단 관계자는 글을 보자마자 구매자로 위장해 A씨와 접촉을 시도했다. A씨는 “정말 살 생각이 있느냐” “돈을 먼저 보여달라” “먼저 입금해 달라”며 수차례 접촉 장소 변경을 요구했다. 결국 조사단원은 제조업체 창고에서 A씨를 만났다.
#
#
#
# 창고에는 ‘박스 갈이(택배 상자에 옮겨 담은 것)’한 마스크 박스 수백 상자가 가득 쌓여있었다. 조사결과 A씨는 7억원 어치 마스크를 14억원에 판매하려고 한 것으로 나타났다. 홍헌우 조사단장은 “105만장은 매점매석 행위 단속을 시작한 후 역대 최대 규모”라며 “마스크 거래처를 찾는 업자가 중고거래 사이트로 몰리고 있다”고 설명했다. 조사단은 A씨 등을 경찰에 고발할 예정이다.
#
#
#
# 식약처 위해사범중앙조사단이 지난 6일 경기도 용인의 한 마스크 도매업체 창고에서 사재기 행위를 단속하고 있다. [연합뉴스]
#
#
#
# 정부가 판단하는 매점매석 기준은 조사 당일 기준으로 지난해 월평균 판매량의 150%를 초과해 5일 이상 보관할 경우다. 지난해 신규 사업자는 영업 시작일부터 조사 당일까지 월평균 판매량을 기준으로 매점매석 여부를 판단한다. 영업 2개월 미만 사업자는 매입한 날부터 10일 이내에 반환ㆍ판매하지 않을 경우 해당한다. 조사단은 해당 업체 마스크 보관량이 지난해 월평균 판매량의 150%가 넘는 만큼 사재기로 보고 있다. 매점매석 행위는 물가안정에 관한 법률에 따라 2년 이하 징역 혹은 5000만원 이하 벌금형을 받을 수 있다.
#
#
#
# 조사단은 국내 ‘마스크 대란’을 돈벌이로 활용하기 위해 여전히 재고물량을 쌓아놓은 업체가 많은 것으로 보고 있다. 지난 6일 기준 국내 마스크 1일 생산 규모는 900만장이다. 신종 코로나 발병 이전 하루 200만~300만장 규모에서 크게 늘었다. 식약처가 이번에 적발한 업체 한 곳에서만 국내 하루 생산량의 10%가 넘는 마스크를 보관하고 있었다.
#
#
#
# 정부는 마스크 사재기 단속 강도를 높이고 있다. 지난 4일부터 식약처와 경찰ㆍ관세청 등이 참여한 정부합동단속반을 확대 운영하고 매점매석 행위 금지를 고시했다. 고시 이틀 만에 700여건의 신고가 접수될 정도로 불법행위는 극성을 부렸다. 11일부터는 1976년 이후 44년 만에 마스크 ‘긴급수급조정조치’를 시행할 계획이다. 조치를 시행하면 마스크 생산ㆍ판매자가 생산량ㆍ판매량ㆍ단가 등을 의무 신고해야 한다. 기획재정부 관계자는 “마스크 생산→유통→판매로 이어지는 전 과정이 투명해져 사재기나 해외 밀반출 가능성을 사전에 차단할 것으로 기대한다”고 말했다.
#
#
#
# 세종=김기환 기자 khkim@joongang.co.kr

# %%
with open(file_path_1, 'r') as f:
    lines = f.readlines()
    print(lines)
    print(type(lines))
# Out:
# ['새로운 내용을 쓰고 싶다면,\n', '이렇게 작성하면 됩니다.']
# <class 'list'>
