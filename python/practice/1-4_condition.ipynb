# %% [markdown]
# # 조건문 만들기

# %% [markdown]
# ## 비교연산자

# %%
a = 3
b = 5

a < b
# Out:
# True

# %%
c = 3
d = 3

c <= d
# Out:
# True

# %%
c != d
# Out:
# False

# %% [markdown]
# ## 논리 연산자 : and / or / not

# %% [markdown]
# ### and

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %% [markdown]
# ### or

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %% [markdown]
# ### not

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %% [markdown]
# ### in

# %% [markdown]
# + 해당 자료형의 요소인지 파악하기 : in / not in

# %%
e = [1, 3, 5, 7]

# %%
0 in e
# Out:
# False

# %%
1 in e
# Out:
# True

# %%
2 not in e
# Out:
# True

# %%
3 not in e
# Out:
# False

# %% [markdown]
# # if / else

# %%
if 조건 :
    수행 할 문장1
    수행 할 문장2
else :
    수행 할 문장3
    수행 할 문장4

# %%
money = True

if money :
    print("여행을 간다")
else :
    print("집에서 쉰다")
# Out:
# 여행을 간다

# %% [markdown]
# # if / elif / else

# %%
if 조건1 :
    수행 할 문장1
elif 조건2 :
    수행 할 문장2
else :
    수행 할 문장3

# %%
money = 20000

if money < 5000 :
    print('라면을 먹는다')
elif 5000 < money < 25000 :
    print('치킨을 먹는다')
elif 25000 < money < 50000 :
    print('삼겹살을 먹는다')
else :
    print('소고기를 먹는다')
# Out:
# 치킨을 먹는다

# %% [markdown]
# # 연습문제 5

# %% [markdown]
# ## 1번
# a와 b가 주어졌을 때, a 곱하기 b가 30 초과면 실패, 30이하면 성공이 출력되도록 만들어보자.

# %%
a = 6
b = 3

# %%
# 정답을 작성해 주세요.
# Out:
# 성공

# %% [markdown]
# ## 2번
# b로 a를 나눈 나머지가 3 초과면 실패, 3이면 무승부, 3 미만이면 성공이 출력되도록 만들어 보자

# %%
a = 3
b = 4

# %%
# 정답을 작성해 주세요.

# %%
# 정답을 작성해 주세요.
# Out:
# 무승부

# %% [markdown]
# ###  pass

# %%
money = 20000
card = True

# %%
if card :
    if money < 30000 :
        print("삼겹살을 먹는다")
    else :
        print("소고기를 먹는다")
else :
    if money <= 1000 :
        pass
    else :
        print("라면을 먹는다")
# Out:
# 삼겹살을 먹는다

# %%
money = 1000
card = False

# %%
if card :
    if money < 30000 :
        print("삼겹살을 먹는다")
    else :
        print("소고기를 먹는다")
else :
    if money <= 1000 :
        pass
    else :
        print("라면을 먹는다")

# %% [markdown]
# # 연습문제 6

# %% [markdown]
# ## 1번
# 다음 코드를 실행했을 때의 결과를 예측해보자

# %%
3 <= 6

# %%
15 % 8 == 3

# %%
298 % 100 < 5

# %%
tmp = []
if tmp :
    print('Not empty!')
else :
    print("empty!")

# %%
tmp2 = [1,5,8,'e','n','.']

if 3 not in tmp2 :
    print("X")
else : 
    print("O")

# %% [markdown]
# ## 2번
# 정부에서는 여름철 전력수급에 차질이 없도록 하기 위해서 실내온도가 26도이상일때만 에어컨을 사용할 수 있도록 권유하고 있다. 이에 맞춰 회사에서는 중앙냉난방을 제어하려고한다.
# 실내온도가 26도 미만일 경우 ‘선풍기’, 26도 이상일 경우 ‘에어컨’을 알려주도록 코딩을 해보자. (화면에 각 단어를 출력하기)
# 실제로 잘 작동하는지 온도를 바꾸어가면서 확인해봅시다.

# %%
temp = 29

# %%
# 정답을 작성해 주세요.
# Out:
# 에어컨

# %% [markdown]
# ## 3번
# 숫자의 자릿수를 판별하는 기계를 만들려고 한다. 한자리수일 경우 1, 두자리 수 일 경우 2, 세자리 수 일 경우 3을 출력하는 조건문을 만들어보자.(주어지는 숫자는 세자리수 이하이다.)

# %%
num = 78

# %%
# 정답을 작성해 주세요.
# Out:
# 2

# %%
# 정답을 작성해 주세요.
# Out:
# 2
