# %%
import os
import matplotlib.pyplot as plt
import tensorflow as tf
import numpy as np
import cv2
from google.colab.patches import cv2_imshow
names=['cat', 'dog'] ## names[0]= cat, names[1]=dog

# %%
model = tf.keras.models.load_model('sample_data/cats_and_dogs_aug_binary_classification.hdf5')  # 모델을 새로 불러옴
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-12-1d2cff0efa93> in <module>()
# ----> 1 model = tf.keras.models.load_model('sample_data/cats_and_dogs_aug_binary_classification.hdf5')  # 모델을 새로 불러옴
#       2
#
# /usr/local/lib/python3.7/dist-packages/keras/saving/save.py in load_model(filepath, custom_objects, compile, options)
#     199             (isinstance(filepath, h5py.File) or h5py.is_hdf5(filepath))):
#     200           return hdf5_format.load_model_from_hdf5(filepath, custom_objects,
# --> 201                                                   compile)
#     202
#     203         filepath = path_to_string(filepath)
#
# /usr/local/lib/python3.7/dist-packages/keras/saving/hdf5_format.py in load_model_from_hdf5(filepath, custom_objects, compile)
#     165   opened_new_file = not isinstance(filepath, h5py.File)
#     166   if opened_new_file:
# ...

# %%
capture = cv2.VideoCapture('sample_data/dog_video.mp4')
#capture.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
#capture.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)

# %%
while True:
    ret, frame = capture.read()  ## ret =True or False // frame 웹캠으로 순간 캡쳐된 이미지

    if ret == False or ret ==False:
        continue
    
    img_resize = cv2.resize(frame, (128, 128))
    test_image_reshape = img_resize.reshape(1, 128, 128, 3).astype('float32')
    
    y = model.predict(test_image_reshape)
    ## y=[[0.6]]
    if y[0] <= 0.5:
        class_num = 0
    else:
        class_num = 1
    class_name=names[class_num]  ## y= [[0.9 , 0.1]]

    location = (10, 20 + 20)
    cv2.putText(frame, str(class_name) +str(y[0]), location, cv2.FONT_ITALIC, 1, (0, 255, 0), 2)
    
    #cv2.imshow("VideoFrame", frame)
    cv2_imshow(frame)

    if cv2.waitKey(1) > 0: break
