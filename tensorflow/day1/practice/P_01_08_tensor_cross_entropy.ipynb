# %%
import tensorflow as tf

## data 선언
x_data = [[2.], [4.], [6.], [8.], [10.], [12.], [14.]]
y_data = [[0.], [0.], [0.], [1.], [1.], [1.], [1.]]
test_data= [[3.]]
test_data2= [[7.]]
test_data3= [[17.]]
test_data4= [[60.]]

# %%
## tf.keras를 활용한 perceptron 모델 구현.
model = tf.keras.Sequential() ## 모델 선언
model.add(tf.keras.layers.Dense(1, input_dim=1, activation='sigmoid')) # 선언된 모델에 add를통해 쌓아감.은닉층
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 모델 loss, 학습 방법 결정하기
optimizer=tf.keras.optimizers.SGD(learning_rate=0.08)   ### 경사 하강법으로 global min 에 찾아가는 최적화 방법 선언.
loss=tf.keras.losses.binary_crossentropy   ## 예측값 과 정답의 오차값 정의. mse는 mean squre error로 (예측값 - 정답)^2 를 의미
metrics=tf.keras.metrics.binary_accuracy  ### 학습하면서 평가할 메트릭스 선언언

# 모델 컴파일하기 - 모델 및 loss 등 구조화한 모델을 컴퓨터가 동작 할수 있도록 변환
model.compile(loss=loss, optimizer=optimizer, metrics=[metrics])

# 모델 동작하기
model.fit(x_data, y_data, epochs=1500, batch_size=2)
# Out:
# Epoch 1/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1321 - binary_accuracy: 1.0000
# Epoch 2/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1077 - binary_accuracy: 1.0000
# Epoch 3/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1254 - binary_accuracy: 1.0000
# Epoch 4/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1607 - binary_accuracy: 0.8571
# Epoch 5/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1334 - binary_accuracy: 1.0000
# Epoch 6/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1528 - binary_accuracy: 0.8571
# Epoch 7/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1440 - binary_accuracy: 0.8571
# Epoch 8/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1278 - binary_accuracy: 1.0000
# Epoch 9/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1514 - binary_accuracy: 0.8571
# Epoch 10/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1461 - binary_accuracy: 0.8571
# Epoch 11/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1068 - binary_accuracy: 1.0000
# Epoch 12/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1260 - binary_accuracy: 1.0000
# Epoch 13/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1064 - binary_accuracy: 1.0000
# Epoch 14/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1296 - binary_accuracy: 1.0000
# Epoch 15/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1496 - binary_accuracy: 0.8571
# Epoch 16/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1493 - binary_accuracy: 0.8571
# Epoch 17/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1331 - binary_accuracy: 1.0000
# Epoch 18/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1301 - binary_accuracy: 1.0000
# Epoch 19/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1336 - binary_accuracy: 1.0000
# Epoch 20/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1550 - binary_accuracy: 0.8571
# Epoch 21/1500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1378 - binary_accuracy: 1.0000
# Epoch 22/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1116 - binary_accuracy: 1.0000
# Epoch 23/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1343 - binary_accuracy: 1.0000
# Epoch 24/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1282 - binary_accuracy: 1.0000
# Epoch 25/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1066 - binary_accuracy: 1.0000
# Epoch 26/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1271 - binary_accuracy: 1.0000
# Epoch 27/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1233 - binary_accuracy: 1.0000
# Epoch 28/1500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1520 - binary_accuracy: 1.0000
# Epoch 29/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1843 - binary_accuracy: 1.0000
# Epoch 30/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1577 - binary_accuracy: 1.0000
# Epoch 31/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1304 - binary_accuracy: 1.0000
# Epoch 32/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1241 - binary_accuracy: 1.0000
# Epoch 33/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1264 - binary_accuracy: 1.0000
# Epoch 34/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1318 - binary_accuracy: 1.0000
# Epoch 35/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1250 - binary_accuracy: 1.0000
# Epoch 36/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1062 - binary_accuracy: 1.0000
# Epoch 37/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1232 - binary_accuracy: 1.0000
# Epoch 38/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1024 - binary_accuracy: 1.0000
# Epoch 39/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1191 - binary_accuracy: 1.0000
# Epoch 40/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1260 - binary_accuracy: 1.0000
# Epoch 41/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1039 - binary_accuracy: 1.0000
# Epoch 42/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1210 - binary_accuracy: 1.0000
# Epoch 43/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1226 - binary_accuracy: 1.0000
# Epoch 44/1500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1241 - binary_accuracy: 1.0000
# Epoch 45/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1176 - binary_accuracy: 1.0000
# Epoch 46/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1304 - binary_accuracy: 1.0000
# Epoch 47/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1246 - binary_accuracy: 1.0000
# Epoch 48/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1355 - binary_accuracy: 0.8571
# Epoch 49/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1187 - binary_accuracy: 1.0000
# Epoch 50/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1213 - binary_accuracy: 1.0000
# Epoch 51/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1496 - binary_accuracy: 1.0000
# Epoch 52/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1197 - binary_accuracy: 1.0000
# Epoch 53/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1022 - binary_accuracy: 1.0000
# Epoch 54/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1256 - binary_accuracy: 1.0000
# Epoch 55/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1234 - binary_accuracy: 1.0000
# Epoch 56/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1244 - binary_accuracy: 1.0000
# Epoch 57/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1179 - binary_accuracy: 1.0000
# Epoch 58/1500
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1188 - binary_accuracy: 1.0000
# Epoch 59/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1220 - binary_accuracy: 1.0000
# Epoch 60/1500
# 4/4 [==============================] - 0s 7ms/step - loss: 0.1233 - binary_accuracy: 1.0000
# Epoch 61/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1243 - binary_accuracy: 1.0000
# Epoch 62/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1182 - binary_accuracy: 1.0000
# Epoch 63/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1524 - binary_accuracy: 1.0000
# Epoch 64/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1176 - binary_accuracy: 1.0000
# Epoch 65/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1401 - binary_accuracy: 0.8571
# Epoch 66/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1272 - binary_accuracy: 1.0000
# Epoch 67/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1178 - binary_accuracy: 1.0000
# Epoch 68/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1211 - binary_accuracy: 1.0000
# Epoch 69/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1189 - binary_accuracy: 1.0000
# Epoch 70/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1288 - binary_accuracy: 1.0000
# Epoch 71/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1177 - binary_accuracy: 1.0000
# Epoch 72/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1259 - binary_accuracy: 1.0000
# Epoch 73/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1199 - binary_accuracy: 1.0000
# Epoch 74/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0987 - binary_accuracy: 1.0000
# Epoch 75/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1257 - binary_accuracy: 1.0000
# Epoch 76/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1175 - binary_accuracy: 1.0000
# Epoch 77/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1251 - binary_accuracy: 1.0000
# Epoch 78/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1195 - binary_accuracy: 1.0000
# Epoch 79/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1214 - binary_accuracy: 1.0000
# Epoch 80/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1177 - binary_accuracy: 1.0000
# Epoch 81/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1185 - binary_accuracy: 1.0000
# Epoch 82/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1197 - binary_accuracy: 1.0000
# Epoch 83/1500
# 4/4 [==============================] - 0s 1ms/step - loss: 0.1450 - binary_accuracy: 1.0000
# Epoch 84/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1312 - binary_accuracy: 0.8571
# Epoch 85/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1104 - binary_accuracy: 1.0000
# Epoch 86/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0974 - binary_accuracy: 1.0000
# Epoch 87/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1165 - binary_accuracy: 1.0000
# Epoch 88/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.0972 - binary_accuracy: 1.0000
# Epoch 89/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1144 - binary_accuracy: 1.0000
# Epoch 90/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1171 - binary_accuracy: 1.0000
# Epoch 91/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1159 - binary_accuracy: 1.0000
# Epoch 92/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1235 - binary_accuracy: 1.0000
# Epoch 93/1500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1004 - binary_accuracy: 1.0000
# Epoch 94/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1134 - binary_accuracy: 1.0000
# Epoch 95/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1427 - binary_accuracy: 1.0000
# Epoch 96/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1211 - binary_accuracy: 1.0000
# Epoch 97/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1119 - binary_accuracy: 1.0000
# Epoch 98/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1182 - binary_accuracy: 1.0000
# Epoch 99/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1376 - binary_accuracy: 1.0000
# Epoch 100/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1246 - binary_accuracy: 1.0000
# Epoch 101/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1356 - binary_accuracy: 1.0000
# Epoch 102/1500
# 4/4 [==============================] - 0s 2ms/step - loss: 0.1190 - binary_accuracy: 1.0000
# Epoch 103/1500
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1226 - binary_accuracy: 1.0000
# Epoch 104/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1173 - binary_accuracy: 1.0000
# Epoch 105/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1354 - binary_accuracy: 1.0000
# Epoch 106/1500
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1356 - binary_accuracy: 1.0000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-5-62018d6bb6db> in <module>()
#       9
#      10 # 모델 동작하기
# ---> 11 model.fit(x_data, y_data, epochs=1500, batch_size=2)
#      12
#      13
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1169           self._maybe_load_initial_epoch_from_ckpt(initial_epoch))
#    1170       logs = None
# -> 1171       for epoch, iterator in data_handler.enumerate_epochs():
#    1172         self.reset_metrics()
#    1173         callbacks.on_epoch_begin(epoch)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/data_adapter.py in enumerate_epochs(self)
#    1202           break
#    1203         if self._adapter.should_recreate_iterator():
# -> 1204           data_iterator = iter(self._dataset)
#    1205         yield epoch, data_iterator
#    1206         self._adapter.on_epoch_end()
#
# KeyboardInterrupt:

# %%
# 결과를 출력합니다.
print(" test data [3.] 예측 값 : ", model.predict(test_data))
print(" test data [7.] 예측 값 : ", model.predict(test_data2))
print(" test data [17.] 예측 값 : ", model.predict(test_data3))
print(" test data [60.] 예측 값 : ", model.predict(test_data4))
