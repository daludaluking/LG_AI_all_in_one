# %%
import tensorflow as tf

### 상수 선언하기.
x1 = tf.constant(8)
x2 = tf.constant(3)
x3 = tf.constant(2)

print(x3)
##  연산
add_result = tf.add(x2,x3)
sub_result = tf.subtract(x1, x2)

x3 = sub_result
print(x3)

print("add_result = {}".format(add_result))
print("sub_result = {}".format(sub_result))
# Out:
# tf.Tensor(2, shape=(), dtype=int32)
# tf.Tensor(5, shape=(), dtype=int32)
# add_result = 5
# sub_result = 5

# %%
### 변수 선언하기.
x1 = tf.Variable(5)
x2 = tf.Variable(3)
x3 = tf.Variable(2)

##  연산
add_result = tf.add(x2,x3)
sub_result = tf.subtract(x1, x2)

print("add_result = {}".format(add_result))
print("sub_result = {}".format(sub_result))
# Out:
# add_result = 5
# sub_result = 2

# %%
### 변수 랜덤 선언하기.
## 평균이 0, 분산 1의 파라마터의 정규분포로 부터 값을 가져옴
x1 = tf.Variable(tf.random.normal((1,1),mean=0, stddev=1.0))
x2 = tf.Variable(tf.random.normal((1,1),mean=0, stddev=1.0))
x3 = tf.Variable(tf.random.normal((1,1),mean=0, stddev=1.0))

##  연산
add_result = tf.add(x2,x3)
sub_result = tf.subtract(x1, x2)

print("add_result = {}".format(add_result))
print("sub_result = {}".format(sub_result))
# Out:
# add_result = [[-0.4647475]]
# sub_result = [[-0.01222715]]

# %%
### 다차원 변수 선언하기.
x1 = tf.Variable([[1,2],[3,4]])

print("x1 = {}".format(x1))
print("x1 = {}".format(x1.shape))
# Out:
# x1 = <tf.Variable 'Variable:0' shape=(2, 2) dtype=int32, numpy=
# array([[1, 2],
#        [3, 4]], dtype=int32)>
# x1 = (2, 2)

# %%
### 위에서 선언산 x1의 shape를 변경 (2,2) -> (1,4)
x1_reshape = tf.reshape(x1,[1,4])

print("x1 = {}".format(x1_reshape))
print("x1 = {}".format(x1_reshape.shape))
# Out:
# x1 = [[1 2 3 4]]
# x1 = (1, 4)

# %% [markdown]
# # 새 섹션

# %% [markdown]
# # 새 섹션

# %%
## tf 객체와 numpy 연상이 가능. 

import numpy as np

### 변수 선언하기.
x1 = tf.Variable(5)
x2 = np.array(3)
x3 = tf.Variable(2)

##  연산
add_result = tf.add(x2,x3)
sub_result = tf.subtract(x1, x2)

print("add_result = {}".format(add_result))
print("sub_result = {}".format(sub_result))
# Out:
# add_result = 5
# sub_result = 2
