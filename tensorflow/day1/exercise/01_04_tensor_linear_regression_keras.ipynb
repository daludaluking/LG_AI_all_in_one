# %%
import tensorflow as tf

## data 선언
x_data =[[1.],[2.],[3.],[4.]]
y_data =[[1.],[3.],[5.],[7.]]

test_data=[[9.], [10.]]

# %%
## tf.keras를 활용한 perceptron 모델 구현.
model = tf.keras.models.Sequential()
model.add( tf.keras.layers.Dense(1, input_dim=1) ) # 선언된 모델에 add를 통해 쌓아감. , 현재는 입력 변수 갯수 1, perceptron 1개.
model.summary() ## 설계한 모델 프린트
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_4 (Dense)              (None, 1)                 2
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 모델 loss, 학습 방법 결정하기
optimizer=  tf.keras.optimizers.SGD(learning_rate=0.01)### 경사 하강법으로 global min 에 찾아가는 최적화 방법 선언.
loss=  tf.keras.losses.mse ## 예측값 과 정답의 오차값 정의. mse는 mean squre error로 (예측값 - 정답)^2 를 의미
metrics=  tf.keras.metrics.mae   ### 학습하면서 평가할 메트릭스 선언 mae는 mean_absolute_error |예측값 - 정답| 를 의미

# 모델 컴파일하기
model.compile(loss=loss, optimizer=optimizer, metrics=[metrics])

# 모델 동작하기
model.fit(x_data, y_data,   epochs=500, batch_size=4)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 275ms/step - loss: 80.4930 - mean_absolute_error: 8.0149
# Epoch 2/500
# 1/1 [==============================] - 0s 5ms/step - loss: 56.0520 - mean_absolute_error: 6.6274
# Epoch 3/500
# 1/1 [==============================] - 0s 4ms/step - loss: 39.0917 - mean_absolute_error: 5.4717
# Epoch 4/500
# 1/1 [==============================] - 0s 5ms/step - loss: 27.3222 - mean_absolute_error: 4.5092
# Epoch 5/500
# 1/1 [==============================] - 0s 4ms/step - loss: 19.1544 - mean_absolute_error: 3.7076
# Epoch 6/500
# 1/1 [==============================] - 0s 5ms/step - loss: 13.4857 - mean_absolute_error: 3.0400
# Epoch 7/500
# 1/1 [==============================] - 0s 4ms/step - loss: 9.5512 - mean_absolute_error: 2.4840
# Epoch 8/500
# 1/1 [==============================] - 0s 5ms/step - loss: 6.8199 - mean_absolute_error: 2.1200
# Epoch 9/500
# ...

# %%
# 결과를 출력합니다.
print(model.summary())
print(model.weights)
print(" test data [9.] 예측 값 : ", model.predict(test_data))
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_4 (Dense)              (None, 1)                 2
# ...
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________
# None
# [<tf.Variable 'dense_4/kernel:0' shape=(1, 1) dtype=float32, numpy=array([[1.8484285]], dtype=float32)>, <tf.Variable 'dense_4/bias:0' shape=(1,) dtype=float32, numpy=array([-0.5543609], dtype=float32)>]
#  test data [9.] 예측 값 :  [[16.081495]
#  [17.929924]]

# %% [markdown]
# [<tf.Variable 'dense/kernel:0' shape=(1, 1) dtype=float32, numpy=array([[1.9916427]], dtype=float32)>, <tf.Variable 'dense/bias:0' shape=(1,) dtype=float32, numpy=array([-0.97536117], dtype=float32)>]
#  test data [9.] 예측 값 :  [[16.949423]]
