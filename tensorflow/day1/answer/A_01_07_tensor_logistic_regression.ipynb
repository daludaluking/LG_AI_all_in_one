# %%
import tensorflow as tf

## data 선언
x_data = [[5.], [30.], [95.], [100.], [265.], [270.], [290.], [300.],[365.]]
y_data = [[0.], [0.], [0.], [0.], [1.], [1.], [1.], [1.], [1.]]
test_data= [[7.]]
test_data2= [[80.]]
test_data3= [[110.]]
test_data4= [[180.]]
test_data5= [[320.]]

# %%
## tf.keras를 활용한 perceptron 모델 구현.
model = tf.keras.Sequential() ## 모델 선언
model.add(tf.keras.layers.Dense(1, input_dim=1,activation='sigmoid')) # 선언된 모델에 add를통해 쌓아감.은닉층
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 1)                 2
# =================================================================
# Total params: 2
# Trainable params: 2
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 모델 loss, 학습 방법 결정하기
optimizer=tf.keras.optimizers.SGD(learning_rate=0.007) ### 경사 하강법으로 global min 에 찾아가는 최적화 방법 선언.
loss=tf.keras.losses.mean_squared_error  ## 예측값 과 정답의 오차값 정의. mse는 mean squre error로 (예측값 - 정답)^2 를 의미
metrics=tf.keras.metrics.binary_accuracy

# 모델 컴파일하기 - 모델 및 loss 등 구조화한 모델을 컴퓨터가 동작 할수 있도록 변환
model.compile(loss=loss, optimizer=optimizer, metrics=[metrics])
# tf.keras.metrics.mean_absolute_percentage_error
# 모델 동작하기
model.fit(x_data, y_data, epochs=3000, batch_size=9)
# Out:
# Epoch 1/3000
# 1/1 [==============================] - 1s 696ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 2/3000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 3/3000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 4/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 5/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 6/3000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 7/3000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 8/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 9/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 10/3000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 11/3000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 12/3000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 13/3000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 14/3000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 15/3000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 16/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 17/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 18/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 19/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 20/3000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 21/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 22/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 23/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 24/3000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 25/3000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 26/3000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 27/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 28/3000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 29/3000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 30/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 31/3000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 32/3000
# 1/1 [==============================] - 0s 19ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 33/3000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 34/3000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 35/3000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 36/3000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 37/3000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 38/3000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 39/3000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 40/3000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 41/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 42/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 43/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 44/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 45/3000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 46/3000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 47/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 48/3000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 49/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 50/3000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 51/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 52/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 53/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 54/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 55/3000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 56/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 57/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 58/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 59/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 60/3000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 61/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 62/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 63/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 64/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 65/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 66/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 67/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 68/3000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 69/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 70/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 71/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 72/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 73/3000
# 1/1 [==============================] - 0s 11ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 74/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 75/3000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 76/3000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 77/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 78/3000
# 1/1 [==============================] - 0s 16ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 79/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 80/3000
# 1/1 [==============================] - 0s 14ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 81/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 82/3000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 83/3000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 84/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 85/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 86/3000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 87/3000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 88/3000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 89/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 90/3000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 91/3000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 92/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 93/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 94/3000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 95/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 96/3000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 97/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 98/3000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 99/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 100/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 101/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 102/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 103/3000
# 1/1 [==============================] - 0s 9ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 104/3000
# 1/1 [==============================] - 0s 7ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 105/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 106/3000
# 1/1 [==============================] - 0s 13ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 107/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 108/3000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 109/3000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 110/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 111/3000
# 1/1 [==============================] - 0s 4ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 112/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 113/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 114/3000
# 1/1 [==============================] - 0s 8ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 115/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 116/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 117/3000
# 1/1 [==============================] - 0s 5ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 118/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 119/3000
# 1/1 [==============================] - 0s 6ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 120/3000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# Epoch 121/3000
# 1/1 [==============================] - 0s 10ms/step - loss: 0.4438 - binary_accuracy: 0.5556
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-a9d2118c7667> in <module>()
#       8 # tf.keras.metrics.mean_absolute_percentage_error
#       9 # 모델 동작하기
# ---> 10 model.fit(x_data, y_data, epochs=3000, batch_size=9)
#      11
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1169           self._maybe_load_initial_epoch_from_ckpt(initial_epoch))
#    1170       logs = None
# -> 1171       for epoch, iterator in data_handler.enumerate_epochs():
#    1172         self.reset_metrics()
#    1173         callbacks.on_epoch_begin(epoch)
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/data_adapter.py in enumerate_epochs(self)
#    1202           break
#    1203         if self._adapter.should_recreate_iterator():
# -> 1204           data_iterator = iter(self._dataset)
#    1205         yield epoch, data_iterator
#    1206         self._adapter.on_epoch_end()
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/dataset_ops.py in __iter__(self)
#     484     if context.executing_eagerly() or ops.inside_function():
#     485       with ops.colocate_with(self._variant_tensor):
# --> 486         return iterator_ops.OwnedIterator(self)
#     487     else:
#     488       raise RuntimeError("__iter__() is only supported inside of tf.function "
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/iterator_ops.py in __init__(self, dataset, components, element_spec)
#     694       if (components is not None or element_spec is not None):
#     695         raise ValueError(error_message)
# --> 696       self._create_iterator(dataset)
#     697
#     698   def _create_iterator(self, dataset):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/data/ops/iterator_ops.py in _create_iterator(self, dataset)
#     717               output_types=self._flat_output_types,
#     718               output_shapes=self._flat_output_shapes))
# --> 719       gen_dataset_ops.make_iterator(ds_variant, self._iterator_resource)
#     720       # Delete the resource when this object is deleted
#     721       self._resource_deleter = IteratorResourceDeleter(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/gen_dataset_ops.py in make_iterator(dataset, iterator, name)
#    3119     try:
#    3120       _result = pywrap_tfe.TFE_Py_FastPathExecute(
# -> 3121         _ctx, "MakeIterator", name, dataset, iterator)
#    3122       return _result
#    3123     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
# 결과를 출력합니다.
print(" test data [7.] 예측 값 : ", model.predict(test_data))
print(" test data [80.] 예측 값 : ", model.predict(test_data2))
print(" test data [110.] 예측 값 : ", model.predict(test_data3))
print(" test data [180.] 예측 값 : ", model.predict(test_data4))
print(" test data [320.] 예측 값 : ", model.predict(test_data5))
